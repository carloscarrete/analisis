# %% [markdown]
# ![](itd.png)
#
#
# # Análisis de Datos Masivos
# ## Delitos en San Francisco
#
# ## Nombree del docente
# ### José Gabriel Rodriguez Rivas
# ## Nombre del alumno
# ### Calos Alberto Carrete Gómez

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
dataset_path = 'Map-Crime_Incidents-Previous_Three_Months.csv'

# %%
SF = pd.read_csv(dataset_path)
SF.head(5)
# Out:
#    IncidntNum       Category                        Descript DayOfWeek  \
# 0         NaN  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3         NaN  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4         NaN  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  \
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# ...

# %%
SF.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location'],
#       dtype='object')

# %% [markdown]
# ### ¿Cuántas variables se incluyen en el marco de datos de SF (ignore el índice)?
#
# #### Respuesta: 11

# %%
len(SF)
# Out:
# 30760

# %%
SF['Month'] = SF['Date'].apply(lambda row: int(row[0:2]))
SF['Day'] = SF['Date'].apply(lambda row: int(row[3:5]))

# %%
SF.head()
# Out:
#    IncidntNum       Category                        Descript DayOfWeek  \
# 0         NaN  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3         NaN  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4         NaN  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  \
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# ...

# %%
del SF['IncidntNum']

# %%
SF.head()
# Out:
#         Category                        Descript DayOfWeek  \
# 0  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  \
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# 1  COLUMBUS AV / JACKSON ST -122.404418  37.796302
# 2   SUTTER ST / STOCKTON ST -122.406959  37.789435
# ...

# %%
SF.drop('Location', axis=1, inplace=True ) #inplace lo hace de inmediato sin esperar a que se asigne a una variable

# %%
SF.head()
# Out:
#         Category                        Descript DayOfWeek  \
# 0  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  Month  Day
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974      8   31
# 1  COLUMBUS AV / JACKSON ST -122.404418  37.796302      8   31
# ...

# %%
ContarCategorias = SF['Category'].value_counts()
ContarCategorias.tail() #Ultimos 5 o head() primeros 5
# Out:
# SEX OFFENSES, NON FORCIBLE    5
# BAD CHECKS                    3
# GAMBLING                      1
# PORNOGRAPHY/OBSCENE MAT       1
# BRIBERY                       1
# Name: Category, dtype: int64

# %%
ContarCategorias = SF['Category'].value_counts(ascending=True)
ContarCategorias
# Out:
# BRIBERY                           1
# PORNOGRAPHY/OBSCENE MAT           1
# GAMBLING                          1
# BAD CHECKS                        3
# SEX OFFENSES, NON FORCIBLE        5
# LOITERING                         5
# EXTORTION                         7
# STOLEN PROPERTY                   7
# FAMILY OFFENSES                   9
# SUICIDE                          14
# EMBEZZLEMENT                     19
# LIQUOR LAWS                      38
# PROSTITUTION                     44
# ARSON                            60
# RUNAWAY                          61
# DISORDERLY CONDUCT               69
# FORGERY/COUNTERFEITING           88
# DRIVING UNDER THE INFLUENCE      93
# SEX OFFENSES, FORCIBLE          123
# KIDNAPPING                      128
# DRUNKENNESS                     142
# TRESPASS                        259
# WEAPON LAWS                     322
# FRAUD                           574
# SUSPICIOUS OCC                  682
# ROBBERY                         862
# ...

# %% [markdown]
# **Pregunta**: ¿Qué tipo de delitos se cometió más?
#
#
# **Respuesta**: LARCENY/THEFT

# %% [markdown]
# **Pregunta de desafío**: ¿Qué PdDistrict presentaba la mayoría de los incidentes de delitos informados? Proporcione los comandos de Python utilizados para respaldar su respuesta.
#
# **Respuesta**: 6185

# %%
ContarCategorias2 = SF['PdDistrict'].value_counts().head(1)
ContarCategorias2
# Out:
# SOUTHERN    6185
# Name: PdDistrict, dtype: int64

# %% [markdown]
# ### Crear subconjuntos de datos y organizarlos en marcos de datos más pequeños

# %%
CrimenesDeAgosto = SF[SF['Month'] == 8]
CrimenesDeAgosto.head()
# Out:
#         Category                        Descript DayOfWeek  \
# 0  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  Month  Day
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974      8   31
# 1  COLUMBUS AV / JACKSON ST -122.404418  37.796302      8   31
# ...

# %% [markdown]
# **¿Cuántos incidentes de delitos hubo en agosto?**
#
# **Respuesta**: 972

# %%
len(CrimenesDeAgosto)
# Out:
# 9720

# %% [markdown]
# **¿Cuántos robos se informaron en agosto?**
#
# **Respuesta**: 10090

# %%
roboAgosto = SF[(SF['Category'] == 'LARCENY/THEFT') | (SF['Category'] == 'VEHICLE THEFT')]
roboAgosto.head()
len(roboAgosto)
# Out:
# 10090

# %%
#Subconjuto de datos delitos del día 31 de agosto 
Crimenes3108 = SF.query('Month == 8 and Day == 31')
Crimenes3108.head()
# Out:
#         Category                        Descript DayOfWeek  \
# 0  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  Month  Day
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974      8   31
# 1  COLUMBUS AV / JACKSON ST -122.404418  37.796302      8   31
# ...

# %% [markdown]
# ### Graficar datos

# %%
plt.plot(SF['X'],SF['Y'], 'bo')
plt.show()

# %%
distritos = np.unique(SF['PdDistrict']) #Datos unicos
colores_distritos = dict(zip(distritos, range(len(distritos))))
colores_distritos
# Out:
# {'BAYVIEW': 0,
#  'CENTRAL': 1,
#  'INGLESIDE': 2,
#  'MISSION': 3,
#  'NORTHERN': 4,
#  'PARK': 5,
#  'RICHMOND': 6,
#  'SOUTHERN': 7,
#  'TARAVAL': 8,
#  'TENDERLOIN': 9}

# %%
SF['colores_distritos'] = SF['PdDistrict'].apply(lambda row: colores_distritos[row])

# %%
plt.scatter(SF['X'], SF['Y'], c=SF['colores_distritos']) #C es de color y segun el numero de diccionario irá poniendo colores distintos

# %% [markdown]
# ### Trazar gráfico en mapa

# %%
from matplotlib import colors
districts = np.unique(SF['PdDistrict'])
print(list(colors.cnames.values())[0:len(districts)])
# Out:
# ['#F0F8FF', '#FAEBD7', '#00FFFF', '#7FFFD4', '#F0FFFF', '#F5F5DC', '#FFE4C4', '#000000', '#FFEBCD', '#0000FF']

# %%
color_dict = dict(zip(districts, list(colors.cnames.values())[0:-1:len(districts)]))  
color_dict
# Out:
# {'BAYVIEW': '#F0F8FF',
#  'CENTRAL': '#8A2BE2',
#  'INGLESIDE': '#00FFFF',
#  'MISSION': '#FF8C00',
#  'NORTHERN': '#FF1493',
#  'PARK': '#F8F8FF',
#  'RICHMOND': '#4B0082',
#  'SOUTHERN': '#FAFAD2',
#  'TARAVAL': '#B0C4DE',
#  'TENDERLOIN': '#9370DB'}

# %%
map_osm = folium.Map(location=[SF['Y'].mean(), SF['X'].mean()], zoom_start = 12)
plotEvery = 50
obs = list(zip( SF['Y'], SF['X'], SF['PdDistrict']))

for el in obs[0:-1:plotEvery]:
    
    folium.CircleMarker(el[0:2], color=color_dict[el[2]], fill_color=el[2],radius=5).add_to(map_osm)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ![](SNFCO.png)
